# %%
import ollama
import requests
import json

# %%
model = "llama3.2:1b"

# %% [markdown]
# #### Task 1: Interact with deployed LLM via python
#
#
# **Objective:**
#
# Explore different techniques to interact with the deployed LLM.
#
# **Task Description:**
#
# 1. Use Request libaray (HTTP Client) and send a POST request to interact with the LLM: [How To](https://requests.readthedocs.io/en/latest/user/quickstart/#make-a-request)

# %%
# Simple HTTP Request via requests

# Define the URL of the deployed LLM ( this port is forwarded from the docker container to the host system)
url = "http://localhost:11434/api/generate"

# Define the prompt as json
body_json = {
    "model": model,
    "prompt": "Describe Generative AI in two sentences."
}

# ADD HERE YOUR CODE
# HINT: Send the POST request using the json body
response = requests.post(url, json=body_json)

# Check if the request was successful
if response.status_code == 200:
    # Process the response
    response_text = response.text

    # Convert each line to json
    response_lines = response_text.splitlines()
    response_json = [json.loads(line) for line in response_lines]
    for line in response_json:
        # Print the response. No line break
        print(line["response"], end="")
else:
    print("Error:", response.status_code)
# Out:
# Generative AI is a type of artificial intelligence that can create original content, such as text, images, and music, by analyzing patterns and structures learned from large datasets and generating new variations based on those patterns. Unlike traditional machine learning models that rely on labeled data to learn and improve, generative AI can produce high-quality outputs without human supervision or labeling, making it a powerful tool for creative applications like content generation, art, and entertainment.

# %% [markdown]
# **Task Description:**
#
# 2. Use Ollama python library to interact with the LLM: [How To](https://pypi.org/project/ollama/)
#
# - First use method ``ollama.chat(...)``
# - First use method ``ollama.chat(...)`` with ``stream=True``

# %%
# API Call via ollama

# ADD HERE YOUR CODE

response = ollama.chat(model=model, messages=[{'role': 'user', 'content': 'Describe Generative Ai in two sentences'}])


print(response["message"]["content"])
# Out:
# Generative AI refers to a type of artificial intelligence that can create new content, such as text, images, and videos, by learning from and generating patterns and structures it has been trained on. Through this process, generative models like language generators, style transferers, and image stylizers can produce novel and often highly realistic outputs that may not be explicitly programmed or scripted.

# %%
# Streaming API Call via ollama

# Response streaming can be enabled by setting stream=True, 
# modifying function calls to return a Python generator where each part is an object in the stream.

# ADD HERE YOUR CODE

stream = ollama.chat(model=model, messages=[{'role': 'user', 'content': 'Describe Generative Ai in two sentences'}], stream=True)

for chunk in stream:
  print(chunk["message"]["content"], end="", flush=True)
# Out:
# Generative AI refers to a type of artificial intelligence that can create original content, such as text, images, music, and videos, by generating new data based on patterns and structures learned from existing data. This technology uses machine learning algorithms to analyze vast amounts of data and produce novel outputs, often with characteristics similar to human-created works, but with the added advantage of scalability and efficiency.

# %% [markdown]
# #### Task 2: Experimenting with Prompt Techniques
#
# **Objective:**
#
# Objective: Explore different prompt techniques (Zero Shot, One Shot, and Few Shot) by sending different types of prompts to the LLM.
#
# ![image](https://miro.medium.com/v2/resize:fit:1400/format:webp/1*QSpK--jqPiUU_OHuZvtUWA.png)
#
# **Task Description:**
#
# 1. Create three prompts for a sentiment analysis task: a Zero Shot prompt, a One Shot prompt, and a Few Shot prompt. Use the examples from the table above.
# 2. Send these prompts to the LLM and observe the differences in the responses.
# 3. Compare and discuss the responses.

# %%
# ADD HERE YOUR PROMPTS

zero_shot_prompt = """Classify this review: I love the new Restaurant! Sentiment:"""

one_shot_prompt = """Classify this review: I love the new Restaurant! Sentiment:Positive, Classify this review: I don't like the desert. Sentiment:"""

few_shot_prompt = """Classify this review: I love the new Restaurant! Sentiment:Positive, Classify this review: I don't like the desert. Sentiment:Negative, Classify this review: Who would order the Burger? Sentiment:"""

# Stream the responses and print them
for idx, prompt in enumerate([zero_shot_prompt, one_shot_prompt, few_shot_prompt]):
    prompt_type = ["Zero-Shot", "One-Shot", "Few-Shot"][idx]
    print(f"\n--- {prompt_type} Prompt ---\n")
    print(f"User Prompt:\n{prompt}\n")
    
    stream = ollama.chat(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        stream=True,
    )
    
    print("Model Output:")
    for chunk in stream:
        print(chunk["message"]["content"], end="", flush=True)
    print("\n-----------------------------\n")
# Out:
# --- Zero-Shot Prompt ---
#
# User Prompt:
# Classify this review: I love the new Restaurant! Sentiment:
#
# Model Output:
# The sentiment of this review is overwhelmingly positive. The phrase "I love" explicitly expresses the reviewer's strong affection and enthusiasm for the restaurant.
# -----------------------------
#
#
# --- One-Shot Prompt ---
#
# User Prompt:
# Classify this review: I love the new Restaurant! Sentiment:Positive, Classify this review: I don't like the desert. Sentiment:
#
# Model Output:
# I would classify the first review as:
#
# **Overall Positive**: The reviewer loves the restaurant, indicating a generally positive sentiment.
#
# And for the second review:
#
# **Mixed/Unfavorable**: The reviewer does not enjoy the dessert, indicating a negative sentiment towards it.
# -----------------------------
#
#
# --- Few-Shot Prompt ---
#
# User Prompt:
# Classify this review: I love the new Restaurant! Sentiment:Positive, Classify this review: I don't like the desert. Sentiment:Negative, Classify this review: Who would order the Burger? Sentiment:
#
# Model Output:
# Based on the text, here are the classifications:
#
# * The first review is a **Positive Review**.
# * The second review is an **Unclassified/Neutral Review**, as it expresses a neutral opinion about the dessert without indicating whether they liked or disliked it.
# * The third review is a **Negative Review**.
# -----------------------------

# %% [markdown]
# #### Task 3: Prompt Refinement and Optimization
#
# **Objective:**
#
# Refine a prompt to improve the clarity and quality of the LLM's response.
#
# **Task Description:**
#
# - Start with a basic prompt asking the LLM to summarize a paragraph.
# - Refine the prompt by adding specific instructions to improve the summary's quality. (Example: define how long the summary should be, define on which to focus in the summary)

# %%
# Original prompt
original_prompt = "Summarize the following paragraph: Generative AI is a field of artificial intelligence focused on creating new content based on patterns learned from existing data. It has applications in text, image, and music generation, and is increasingly being used in creative industries."

# ADD HERE YOUR PROMPT
refined_prompt = "Summarize the following paragraph in three sentences and focus on the content of Generative AI: Generative AI is a field of artificial intelligence focused on creating new content based on patterns learned from existing data. It has applications in text, image, and music generation, and is increasingly being used in creative industries."

# Stream the responses and print them
for idx, prompt in enumerate([original_prompt, refined_prompt]):
    prompt_type = ["Original Prompt", "Refined Prompt"][idx]
    print(f"\n--- {prompt_type} ---\n")
    print(f"User Prompt:\n{prompt}\n")
    
    stream = ollama.chat(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        stream=True,
    )
    
    print("Model Output:")
    for chunk in stream:
        print(chunk["message"]["content"], end="", flush=True)
    print("\n-----------------------------\n")
# Out:
# --- Original Prompt ---
#
# User Prompt:
# Summarize the following paragraph: Generative AI is a field of artificial intelligence focused on creating new content based on patterns learned from existing data. It has applications in text, image, and music generation, and is increasingly being used in creative industries.
#
# Model Output:
# Generative AI creates new content (text, images, or music) by learning patterns from existing data. It's primarily used in creative fields like writing, art, and music.
# -----------------------------
#
#
# --- Refined Prompt ---
#
# User Prompt:
# Summarize the following paragraph in three sentences and focus on the content of Generative AI: Generative AI is a field of artificial intelligence focused on creating new content based on patterns learned from existing data. It has applications in text, image, and music generation, and is increasingly being used in creative industries.
#
# Model Output:
# Here is a summary of the paragraph in three sentences focusing on generative AI:
#
# Generative AI is an area of artificial intelligence that involves creating new content based on patterns learned from existing data. This field has applications across various domains, including text, image, and music generation, as well as its use in creative industries such as writing, art, and music. The goal of generative AI is to create novel or original content that mimics the style or behavior of existing data, often through complex algorithms and machine learning techniques.
# -----------------------------

# %% [markdown]
# #### [Optional] Task 4: Structured Prompting with Roles (Pirate Theme)
#
# **Objective:**
#
# Learn how to use structured prompts that combine role assignment, clear instructions, and examples to improve the output of language models. In this task, you will guide the AI to respond as a pirate who is also an expert in machine learning.
#
# **Instructions:**
#
# - Role Assignment: In your prompt, specify the role of the AI as a Machine Learning Expert who speaks like a pirate.
#
# - Instruction: Clearly state what you want the AI to explain or discuss in pirate language.
#
# - Examples: Provide examples to guide the AI in using pirate lingo while explaining technical concepts.

# %%
# Combined Techniques Prompt with Pirate Theme

structured_prompt = """You are a machine learning expert who always speaks like a pirate from the high seas. Explain the concept of overfitting in machine learning using pirate-themed language. Your answer should be technically correct but filled with pirate expressions, metaphors, and mannerisms.
"""

# Stream the response and print it
print("=== User Prompt ===")
print(structured_prompt)

stream = ollama.chat(
    model=model,
    messages=[{"role": "user", "content": structured_prompt}],
    stream=True,
)

print("\n=== Model Output ===")
for chunk in stream:
    print(chunk["message"]["content"], end="", flush=True)
print("\n")
# Out:
# === User Prompt ===
# You are a machine learning expert who always speaks like a pirate from the high seas. Explain the concept of overfitting in machine learning using pirate-themed language. Your answer should be technically correct but filled with pirate expressions, metaphors, and mannerisms.
#
#
# === Model Output ===
# Yer lookin' fer a lesson on overfitting, eh? Alright then, matey, settle yerself down with a pint o' grog and listen close.
#
# Overfitting be like tryin' to find the hidden treasure in a sea o' noise. Ye see, when ye fit too many parameters into yer model, ye risk gettin' stuck on one particular treasure map (that be the optimal solution). But that's not the only way to get yer treasure – it be possible to just sail through the waters and expect to find booty whenever ye please.
#
# Imagine ye be buildin' a ship with too many sails. Ye add more and more, thinkin' they'll make it faster and stronger, but in reality, ye be just makin' it bigger and heavier. That be overfitting, matey! The extra sails don't help ye navigate the waters or avoid storms – they just clog up yer riggin'!
#
# Now, let's talk about the curse o' dimensionality. Ye see, when ye have too many features (or dimensions), ye risk gettin' lost in the fog o' complexity. It be like tryin' to find a needle in a haystack, but instead o' a needle, it be a mountain o' data points.
#
# When the number o' parameters exceeds the number o' training examples, ye risk overfitting. The model becomes too specialized and can't generalize well to new data or unseen situations. It's like tryin' to chart a course through treacherous waters with a compass that be stuck in yer ear – ye'll end up gettin' lost!
#
# But don't ye worry, matey! There be ways to avoid overfitting. One way be to use regularization techniques, like L1 or L2 penalization, to reduce the number o' parameters and prevent overfitting. It be like addin' a sea siren's song – it'll keep ye from gettin' too comfortable in yer treasure-filled waters.
#
# Another way be to use cross-validation, matey! Ye see, when ye train yer model on new data, ye be testin' its limits and preventin' overfitting. It be like sailin' through calm seas – ye know ye can trust the navigation!
#
# And finally, don't forget about early stoppin' or k-fold cross-validation, me hearty! These methods will help ye evaluate yer model's performance on unseen data and prevent overfitting.
#
# So there ye have it, matey – overfitting be a pirate's worst enemy. Keep yer wits about ye and use these tactics to navigate the waters o' machine learnin' without gettin' stuck in the sea o' complexity!
